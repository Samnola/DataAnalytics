# %% [markdown]
# # Intro to Jupyter Noteboks
#
# This notebook practices working in `code` and **markdown**  blocks

# %%
print("Hello world")
# Out:
# Hello world

# %%
fruits = ['apple', 'pear', 'plum']

# %%
veggies = ['cauliflower', 'broccoli', 'eggplant']

# %%
print(fruits)
print(veggies)
# Out:
# ['apple', 'pear', 'plum']
# ['cauliflower', 'broccoli', 'eggplant']

# %% [markdown]
# ## Quick example of a loop

# %%
for i in fruits:
    print (i)
# Out:
# apple
# pear
# plum

# %%
for n, i in enumerate(fruits):
    print(n, i)
# Out:
# 0 apple
# 1 pear
# 2 plum

# %%
for peanutbutter, jelly in enumerate(fruits, start=1):
    print(f'{peanutbutter}. {jelly}')
# Out:
# 1. apple
# 2. pear
# 3. plum

# %% [markdown]
# ## String manipulation continued
