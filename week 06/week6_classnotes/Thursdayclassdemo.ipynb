# %%
class SimpleDog:
    '''
    Simple model for a dog
    ''' 
def __init__(self, name, age, he_she, fuzzy='fuzzy'):
    self.name = name
    self.age = age
    self.he_she = he_she
    self.fuzzy = fuzzy
    self.behavior = 'good'
def sit(self): # this is a method
    print(f'{self.name} is now sitting')
def birthday(self):
    self.age +=1
    return f'Happy birthday, {self.name}! {self.name} is now {self.age}'
def behavior(self):
    self.behavior = input(f"How is {self.name} behaving right now?")
    print(f'{self.behavior.title()}dog!')
    self.behavior = 'good'
    return f'{self.he_she} is a {self.behavior} dog'

# %%
luis_dog = SimpleDog('Lola', 8, 'She','short-haired')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 luis_dog = SimpleDog('Lola', 8, 'She','short-haired')
#
# TypeError: SimpleDog() takes no arguments

# %%
print(f'{luis_dog.name} is {luis_dog.fuzzy}')
print(luis_dog.birthday())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(f'{luis_dog.name} is {luis_dog.fuzzy}')
#       2 print(luis_dog.birthday())
#
# NameError: name 'luis_dog' is not defined
