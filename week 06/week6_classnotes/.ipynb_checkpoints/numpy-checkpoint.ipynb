# %% [markdown]
# # Continuing with Numpy

# %%
# lists of lists (stadnard python object)

[[1, 2, 3,], ['a', 'b', 'c']]
# Out:
# [[1, 2, 3], ['a', 'b', 'c']]

# %%
print(example)
# Out:
# [[1, 2, 3], ['a', 'b', 'c']]

# %%
import numpy as np

# %%
example_a = np.array(example)

# %%
print(example)
# Out:
# [[1, 2, 3], ['a', 'b', 'c']]

# %%
example_a.dtype
# Out:
# dtype('<U21')

# %%
# another python list example

example2 = [(10,11),(12,13),(14,15)] # list of tuples only include integers 

example_b = np.array(example2)
print(example_b)
print(example_b.dtype)
# Out:
# [[10 11]
#  [12 13]
#  [14 15]]
# int64

# %%
example3 = ((1.0,1.1),(2.0,2.1)) # tuple of tuples using floats (floats take up more space in memory than integers )

example_c = np.array(example3)
print(example_c)
print(example_c.dtype)
# Out:
# [[1.  1.1]
#  [2.  2.1]]
# float64

# %%
example_d = np.array(example3, dtype='i')

# %%
print(example_d)
print(example_d.dtype)
# Out:
# [[1 1]
#  [2 2]]
# int32

# %%
example_e = np.array(example1, dtype='i') # example 1 includes a mix of int and string values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 example_e = np.array(example1, dtype='i') # example 1 includes a mix of int and string values
#
# NameError: name 'example1' is not defined
