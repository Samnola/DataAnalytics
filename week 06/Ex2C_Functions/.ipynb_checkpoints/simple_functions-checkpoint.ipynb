# %% [markdown]
# ## Lab 1 of Exercise 2.C
# working with defining custom functions

# %%
def favorite_things(name, movie, music):
    print(f"{name} likes {movie} and {music}.")

# %%
favorite_things("Alondra", "La La Land", "salsa")
# Out:
# Alondra likes La La Land and salsa.

# %%
#purpse function
def why_im_here(purpose):
    return f"I joined the year up Data Analyst program because I want to build my technical skills and start a career in data {purpose}."

# %%
print(why_im_here("purpose"))
# Out:
# I joined the year up Data Analyst program because I want to build my technical skills and start a career in data purpose.
