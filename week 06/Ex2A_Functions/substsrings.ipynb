# %% [markdown]
# # Excercise 2.A Using built-in Functions
# ## Lab 1. Working with names - parsing strings

# %%
test_name = "John Doe"

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == " ":
            first = name[:i]
            last = name[i+1:]
            print(f"Full name: {name}")
            print(f"first name: {first}")
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# first name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken penn']

# %%
# output for Grace Flores
for person in test_list:
    parse_and_display(Grace Flores)

# %%
for person in test_list:
    parse_and_display(person)
# Out:
# Full name: Grace Flores
# first name: Grace
# Last name: Flores
# Full name: JB Oinonen
# first name: JB
# Last name: Oinonen
# Full name: Ken penn
# first name: Ken
# Last name: penn

# %%
for person in test_list:
    parse_and_display('Alondra Martinez')
# Out:
# Full name: Alondra Martinez
# first name: Alondra
# Last name: Martinez
# Full name: Alondra Martinez
# first name: Alondra
# Last name: Martinez
# Full name: Alondra Martinez
# first name: Alondra
# Last name: Martinez

# %% [markdown]
# ## parse_and_display2()

# %%
def parse_an_display2(name):
    print(name)

# %%
parse_and_display2("Lorde")
# Out:
# Lorde

# %%
def parse_and_display2(name):
    print(name)

# %%
parse_and_display2("Megan Thee Stallion")
# Out:
# Megan Thee Stallion
