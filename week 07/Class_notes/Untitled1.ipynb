# %% [markdown]
# ## DataFrames Self study

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# Think of a DataFrame as a spreadsheet in Excel or Google Sheets.
#
# this spreadsheet is called a DataFrame.

# %% [markdown]
# DataFrame #1: Sales

# %%
# imagine your information is stored in different spreadsheets

# %%
# df_sales

# %% [markdown]
# DataFrame #2 Product information

# %%
# df_products

# %%
# print(df_sales) Think of this as opening the spreadsheet and looking at the rows and columns.

# %% [markdown]
# Suppose you only want the Revenue column

# %%
# df_sales['Revenue']

# %% [markdown]
# if you want multiple columns

# %%
# df_sales[['Product', 'Revenue']]
